# %% [markdown]
# <a href="https://colab.research.google.com/github/aeron7/alice_blue_pro/blob/main/AliceBlue_Sample_Program_3_Historical_Data_Download_Python_Code_for_any_stock_of_Stock_Market_Using_Ant_API_By_Unofficed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Getting Historical Data

# Alice Blue now supports downloading historical data for back testing.

# Historical data API will be available from 5:30 PM (evening) to 8 AM (Next day morning) on weekdays (Monday to Friday). Historical data will not be available during market hours
# Historical data API will be available fully during weekends and holidays.
# For NSE segment, 2 years of historical data will be provided.
# For NFO, CDS and MCX segments, current expiry data will be provided.

# %%
#Let's install the Library
# !pip install alice_blue
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/krishnavelu/alice_blue.git (to revision develop) to /tmp/pip-req-build-amanqdz9
#   Running command git clone -q https://github.com/krishnavelu/alice_blue.git /tmp/pip-req-build-amanqdz9
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   Branch 'develop' set up to track remote branch 'develop' from 'origin'.
# ...
#      |████████████████████████████████| 4.0 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.0 MB/s
# ...
#   Created wheel for alice-blue: filename=alice_blue-2.0.3-py2.py3-none-any.whl size=35040 sha256=18fdd5ff15e968d2ca07af6677b1f860d6ab45934e102b97e535a3351a76eaae
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gu45e49b/wheels/f6/c8/7c/5fa1c2f0d20829ef7bf42b48667da66482e0971bf2f1cb4dd0
# Successfully built alice-blue
# ...

# %%
#Copying the base code to get the alice function

#Importing AliceBlue Library
from alice_blue import *

#Only Replace it with your credentails
#Follow https://unofficed.com/how-to-activate-the-api-in-alice-blue-for-automated-trading/ for generating api_ID and api_Secret 

#Only Replace it with your credentails
username    = "enter_your_user_name" 
password    = "enter_your_password" 
twoFA       = "enter_byear"
app_id      = "enter_app_id"
api_secret  = "enter_api_secret"

#Generating Session ID
session_id = AliceBlue.login_and_get_sessionID(username=username,password=password,twoFA=twoFA,app_id=app_id,api_secret=api_secret)

#Generate an Alice object using the session_id
alice = AliceBlue(username = username, session_id = session_id, master_contracts_to_download=['NSE', 'BSE','NFO','MCX'])

# %%
#Let's test the sample code provided in Krishna's Library
import datetime #There is use of datetime library in the syntax.
alice.historical_data(alice.get_instrument_by_symbol("NSE", "INFY-EQ"),datetime.datetime(2022, 9, 15),datetime.datetime(2022, 9, 20),HistoricalDataType.Minute)
# Out:
# {'stat': 'Ok',
#  'result': [{'volume': 13692.0,
#    'high': 1435.3,
#    'low': 1434.7,
#    'time': '2022-09-15 11:22:59',
#    'close': 1435.25,
#    'open': 1434.85},
#   {'volume': 17590.0,
#    'high': 1435.95,
#    'low': 1435.25,
#    'time': '2022-09-15 11:23:59',
#    'close': 1435.8,
#    'open': 1435.3},
#   {'volume': 18878.0,
#    'high': 1436.0,
#    'low': 1435.0,
#    'time': '2022-09-15 11:24:59',
#    'close': 1435.85,
#    'open': 1435.8},
#   {'volume': 15943.0,
#    'high': 1436.45,
#    'low': 1435.4,
#    'time': '2022-09-15 11:25:59',
#    'close': 1435.4,
#    'open': 1435.95},
#   {'volume': 10990.0,
#    'high': 1436.0,
#    'low': 1435.3,
#    'time': '2022-09-15 11:26:59',
#    'close': 1435.7,
#    'open': 1435.4},
#   {'volume': 18161.0,
#    'high': 1435.85,
#    'low': 1435.0,
#    'time': '2022-09-15 11:27:59',
#    'close': 1435.05,
#    'open': 1435.7},
#   {'volume': 19567.0,
#    'high': 1435.4,
#    'low': 1435.0,
# ...

# %%
import pandas as pd
#Importing pandas as it involves dataframe.

payload = alice.historical_data(alice.get_instrument_by_symbol("NSE", "INFY-EQ"),datetime.datetime(2022, 9, 15),datetime.datetime(2022, 9, 20),HistoricalDataType.Minute)
print(payload["stat"])
print(payload) #Lets test if everything is fine so far.

#TNo Point of going further if there is problem in fetching the Historical Data. 
if(payload["stat"]=="Ok"):
  payload = payload["result"]

#Now it is a List of JSONs. Lets convert it to dataframe. 
df = pd.DataFrame.from_records(payload)
df
# Out:
# Ok
# ...
